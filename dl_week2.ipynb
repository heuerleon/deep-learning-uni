# %%
import random
from math import exp, log

# %%
x = [(0,0),(1,0),(0,1),(1,1)]
y = [0,0,0,1]

# %%
class logistic_regression_model():
        def __init__(self):
            self.w = [random.random(), random.random()]
            self.b = random.random()

        def sigmoid(self, z):
            return 1/(1 + exp(-z))

        def predict(self, x):
            z = self.w[0] * x[0] + self.w[1] * x[1] + self.b
            a = self.sigmoid(z)
            return a

# %%
model = logistic_regression_model()

# %%
def train(X, Y, model, lr = 0.1):
    dw0 = 0.0
    dw1 = 0.0
    db = 0.0
    m = len(X)
    cost = 0.0
    for x, y in zip(X, Y):
        a = model.predict(x)
        if y == 1:
            cost -= log(a)
        else:
            cost -= log(1-a)

        dw0 += (a-y) * x[0]
        dw1 += (a-y) * x[1]
        db += (a-y)

    cost /= m
    model.w[0] -= lr * dw0/m
    model.w[1] -= lr * dw1/m
    model.b -= lr * db/m

    return cost

# %%
for epoch in range(10000):
    cost = train(x, y, model, 0.1)
    if epoch % 100 == 0:
        print(epoch, cost)
# Out:
# 0 1.191414867214119
# 100 0.4712029057691738
# 200 0.3676970315763508
# 300 0.3045413093958774
# 400 0.26139851296439287
# 500 0.22964462855598647
# 600 0.20506733730105592
# 700 0.18536124787650268
# 800 0.16914654833069592
# 900 0.15553832714598323
# 1000 0.1439378041969888
# 1100 0.13392236184029052
# 1200 0.12518349582230204
# 1300 0.1174897523063357
# 1400 0.11066351362285512
# 1500 0.10456586743701246
# 1600 0.09908640681663558
# 1700 0.09413615399163273
# 1800 0.08964252850585147
# 1900 0.08554569176866227
# 2000 0.08179584144906535
# 2100 0.07835117572677093
# 2200 0.07517633909200824
# 2300 0.0722412202732069
# 2400 0.06952001160754893
# 2500 0.06699046519976161
# 2600 0.06463329904688955
# 2700 0.062431718737671754
# 2800 0.06037102913880661
# 2900 0.058438316805701516
# 3000 0.05662218846022903
# 3100 0.05491255427123297
# 3200 0.053300447201848955
# 3300 0.051777871591038555
# 3400 0.05033767558326085
# 3500 0.04897344312932246
# 3600 0.04767940213888219
# 3700 0.04645034603306714
# 3800 0.045281566469797904
# 3900 0.04416879542849363
# 4000 0.04310815517001543
# 4100 0.04209611485099747
# 4200 0.04112945278348516
# 4300 0.04020522350204597
# 4400 0.03932072893970753
# 4500 0.03847349312774152
# 4600 0.03766123992757443
# 4700 0.036881873379954855
# 4800 0.036133460320090946
# 4900 0.03541421496030423
# 5000 0.034722485185794405
# 5100 0.03405674034598407
# 5200 0.033415560354878956
# 5300 0.03279762593997407
# 5400 0.032201709901301355
# 5500 0.03162666926092143
# 5600 0.031071438199079232
# 5700 0.03053502168681166
# 5800 0.030016489736413507
# 5900 0.029514972201119934
# 6000 0.029029654063929603
# 6100 0.02855977116287091
# 6200 0.02810460630639233
# 6300 0.027663485738080085
# 6400 0.027235775914700326
# 6500 0.02682088056573378
# 6600 0.026418238006206185
# 6700 0.0260273186777919
# 6800 0.025647622895950326
# 6900 0.025278678783288842
# 7000 0.024920040371490773
# 7100 0.024571285856028347
# 7200 0.02423201598954558
# 7300 0.023901852601261393
# 7400 0.023580437231043944
# 7500 0.023267429867955755
# 7600 0.022962507784093502
# 7700 0.02266536445545099
# 7800 0.022375708562344818
# 7900 0.022093263062661614
# 8000 0.021817764331829692
# 8100 0.021548961363991308
# 8200 0.021286615029371493
# 8300 0.021030497383294912
# 8400 0.02078039102272091
# 8500 0.020536088486539462
# 8600 0.020297391696202517
# 8700 0.02006411143357091
# 8800 0.019836066853127252
# 8900 0.019613085025952624
# 9000 0.019395000513085285
# 9100 0.019181654966083626
# 9200 0.018972896752795405
# 9300 0.01876858060650184
# 9400 0.018568567296756378
# 9500 0.018372723320372018
# 9600 0.01818092061113734
# 9700 0.017993036266953505
# 9800 0.017808952293187803
# 9900 0.017628555361133457

# %%
model.predict((0,0))
# Out:
# 1.2527445825256256e-05

# %%
model.predict((0,1))
# Out:
# 0.020280574913242314

# %%
model.predict((1,0))
# Out:
# 0.02028056753918519

# %%
model.predict((1,1))
# Out:
# 0.9715949030116023
